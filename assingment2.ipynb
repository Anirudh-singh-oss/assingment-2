# %% [markdown]
# # data types and structures questions

# %% [markdown]
# 1. what are data structure, and why are they imp?
#
# .  A data structure is a way of organizing and storing data in a computer so that it can be accessed and used efficiently. It refers to the logical or mathematical representation of data, as well as the implementation in a computer program.
#
# 2. second question?
#
# .  In Python, objects can be classified into two categories: mutable and immutable. In simple terms, mutable objects can be changed after they are created, while immutable objects cannot be altered. Everything is an object with a unique ID assigned upon creation
#
# 3. third question?
#
#
# . Tuples are immutable objects and lists are mutable objects. Once defined, tuples have a fixed length and lists have a dynamic length. Tuples use less memory and are faster to access than to lists. Tuple syntax uses round brackets or parenthesis, and list syntax uses square brackets.
#
# 4. fourth question?
#
# . Dictionaries are unordered collections of data and are represented with curly brackets { } . Like lists, dictionaries are mutable(changeable) and indexed. With dictionaries, data is stored in a key:value format. In this example, myCar is the variable that we have assigned our dictionary to.
#
# 5. fifth question?
#
# . Because you don't need the features of a list, but you will check whether it includes items and thus benefit from the improved performance of using a set. Because you don't want duplicates. Because you want to compare one set of items to another without caring about order or duplicates.
#
# 6. sixth question?
#
# . A string is a sequence of characters. A list a sequence of values which can be characters, integers or even another list (referred to as a nested list). A dictionary is a more general version of a list and is made up a set of keys and values where there is a mapping between a given key and its corresponding value.
#
# 7. seventh question?
#
#
# . Tuples are immutable to ensure that their contents remain constant throughout their lifecycle, guaranteeing data integrity and reliability. This immutability allows tuples to be used as keys in dictionaries and elements in sets, as they can be hashed.
#
# 8. eighth question?
#
# . Hash tables in data science
# In Python, the Dictionary data types represent the implementation of hash tables. The Keys in the dictionary are hashable–they are generated by a hash function which generates a unique result for each unique value supplied to the hash function.
#
# 9. ninth question?
#
# .
# However, in Python, lists can contain heterogeneous data types and objects. For instance, integers, strings, and even functions can be stored within the same list.
#
# 10. tenth question?
#
# . Python strings are "immutable" which means they cannot be changed after they are created (Java strings also use this immutable style). Since strings can't be changed, we construct *new* strings as we go to represent computed values.
#
# 11. eleventh question?
#
# . Dictionaries are ideal for tasks requiring quick lookups, data mappings, and key-value associations. Lists are suitable for ordered collections, sequential processing, and scenarios where the order of elements matters.
#
# 12. twelth question?
#
# .
# Lists are mutable, allowing you to modify their content, while tuples are immutable, meaning you can't change them after creation. You should prefer tuples when you need an immutable sequence, such as function return values or constant data
#
# 13. thirteenth question?
#
# . Sets do not allow duplicate items, they are unordered, and the items stored in them cannot be modified.
#
# 14. fourteenth question?
#
# . As mentioned above, the in operation for the dictionary tests on keys. The key of the dictionary is a unique value as well as the set, and the execution time is about the same as for sets. On the other hand, dictionary values can be duplicated like a list
#
# 15. fifteenth question?
#
# . Immutability: Unlike lists, tuples in Python are immutable, meaning you cannot change their elements once the tuple is created. Attempting to modify a tuple results in a TypeError. Duplicates: Tuples can contain duplicates, meaning the same value can appear more than once.
#
# 16. sixteenth question?
#
# . A nested dictionary is a dictionary that contains another dictionary as a value. It helps organize complex or grouped data, like student details or product info in a clean and structured way. Example: Python. # Creating a Nested Dictionary Dict = { 1: 'Geeks', 2: 'For', 3: {'A': 'Welcome', 'B': 'To', 'C': 'Geeks'} }
#
# 17.  seventeenth question?
#
#  .Similar to the insertion operation, dictionary lookups in Python also have an average time complexity of O(1). This means that, on average, the time taken to retrieve an element from a dictionary is constant and does not depend on the size of the dictionary
#
#  18. eighteenth question?
#
#  . f you need an ordered collection, like a sequence of user actions, lists are your go-to. On the other hand, when you need quick look-ups, like mapping usernames to user data, dictionaries are invaluable.
#
#  19 . ninteenth question?
#
#  . A dictionary is termed an unordered collection of objects because dictionaries do not maintain any inherent order of the items based on when they were added. In older versions of Python (before 3.7), dictionaries did not preserve insertion order at all.
#
#  20. twenty question?
#
#  . A list is an ordered collection of items, whereas a dictionary is an unordered data collection in a key: value pair. Elements from the list can be accessed using the index, while the elements of the dictionary can be accessed using keys.

# %% [markdown]
# # practical questions

# %% [markdown]
# 1. first question?

# %%
print("anirudh singh")
# Out:
# anirudh singh

# %% [markdown]
# 2.  second question?

# %%
s= "hello world"
len(s)
# Out:
# 11

# %% [markdown]
# 3. third question?

# %%
var="HELLO PYTHON"
print ("var:",var)
print ("var[3:8]:", var[3:8])
print ("var[-9:-4]:", var[-9:-4])
# Out:
# var: HELLO PYTHON
# var[3:8]: LO PY
# var[-9:-4]: LO PY

# %% [markdown]
# 4. fourth question?

# %%
# Input dictionary
d = {'a': ['hello', 'world'], 'b': ['python', 'programming']}

# Convert strings to uppercase using dictionary and list comprehensions
res = {k: [v.upper() for v in vals] for k, vals in d.items()}

print(res)
# Out:
# {'a': ['HELLO', 'WORLD'], 'b': ['PYTHON', 'PROGRAMMING']}

# %% [markdown]
# fifth question?

# %%
s = "apple apple apple"

# Replace "apple" with "orange" only once
s1 = s.replace("apple", "orange",1 )

print(s1)
# Out:
# orange apple apple

# %% [markdown]
# 6. sixth question

# %%
l=[1,2,3,4,5,]
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# seventh question?

# %%
l=[1,2,3,4,]
l.append(10)

# %%
l
# Out:
# [1, 2, 3, 4, 10]

# %% [markdown]
# 7.seventh question?

# %%
l=[1,2,3,4,5,]
l.remove(3)
l
# Out:
# [1, 2, 4, 5]

# %% [markdown]
# eighth question?

# %%
l=['a','b','c','d']
l[1]
# Out:
# 'b'

# %% [markdown]
# tenth question?

# %%
l=[10,20,30,40,50]
l[::-1]
# Out:
# [50, 40, 30, 20, 10]

# %% [markdown]
# eleventh question?

# %%
t=(100,200,300)
print(t)
# Out:
# (100, 200, 300)

# %% [markdown]
# twelth question?

# %%
t=('red','green','yellow','blue')
t[1:]
# Out:
# ('green', 'yellow', 'blue')

# %% [markdown]
# thirteenth question?

# %%
t=(10,20,5,15)
minimum_no=min(t)
minimum_no
# Out:
# 5

# %% [markdown]
# fourteenth question?

# %%
t=('dog','cat','rabbit')
t.index("cat")
# Out:
# 1

# %% [markdown]
# fifteenth question?

# %%
t=('apple','mango','banana','kiwi')
if "kiwi" in t:
  print("kiwi is  present ")
else:
  print(" kiwi is not present")
# Out:
# kiwi is  present

# %% [markdown]
# 16. sixteenth question

# %%
s={'a','b','c'}
s
# Out:
# {'a', 'b', 'c'}

# %% [markdown]
# 17. seventeenth question?

# %%
s={1,20,3,4,5}
s.clear()
s
# Out:
# set()

# %% [markdown]
# 18. eighteenth question?

# %%
s={1,2,3,4}
s.remove(4)
s
# Out:
# {1, 2, 3}

# %% [markdown]
# 19. ninteenth question?

# %%
s1={1,2,3}
s2={3,4,5}
s1&s2
# Out:
# {3}

# %% [markdown]
# 20 twenty?

# %%
s1={1,2,3}
s2={3,4,5}
s1|s2
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# 21. twenty one question?

# %%
d={'name':"anirudh ",'age':"21",'city':"pratapgarah" }
d
# Out:
# {'name': 'anirudh ', 'age': '21', 'city': 'pratapgarah'}

# %% [markdown]
# 22. twenty two

# %%
d={'name':"anirudh ",'age':"21",'city':"pratapgarah" }
d1={'country':"india"}
d.update(d1)
d
# Out:
# {'name': 'anirudh ', 'age': '21', 'city': 'pratapgarah', 'country': 'india'}

# %% [markdown]
# 23. twenty three question?

# %%
d={'name':"anirudh ",'age':"21",'city':"pratapgarah" }
d['name']
# Out:
# 'anirudh '

# %% [markdown]
# 24. twenty four?

# %%
d={'name':"anirudh ",'age':21,'city':"pratapgarah" }
del d['age']
d
# Out:
# {'name': 'anirudh ', 'city': 'pratapgarah'}

# %% [markdown]
# 25. twenty five question?

# %%
d={'name':"anirudh ",'age':"21",'city':"pratapgarah" }
if "city"in d:
  print('yes')
else:
  print('no')
# Out:
# yes

# %% [markdown]
# 26 . twenty six

# %%
l=[1,20,3,4,[1,2],{'name':"anirudh "},(4,5,6)]
l
# Out:
# [1, 20, 3, 4, [1, 2], {'name': 'anirudh '}, (4, 5, 6)]

# %% [markdown]
# 27. twenty seven question

# %%
l=[2,50,18,9]
l.sort()
l
# Out:
# [2, 9, 18, 50]

# %% [markdown]
# 28 twenty eight question?

# %%
l=['apple','mango','banan','lichi','kiwi']
l[-2]
# Out:
# 'lichi'

# %% [markdown]
# 29 twenty nine question?

# %%
d={'name':"anirudh ",'age':21,'city':"pratapgarah" }
d1={"country":"india" }
{**d,**d1}
# Out:
# {'name': 'anirudh ', 'age': 21, 'city': 'pratapgarah', 'country': 'india'}

# %% [markdown]
# 30.  thirty question

# %%
s = "Geeks"

print(type(s))
print(s)

# Convert String to Set
set_s = set(s)

print(type(set_s))
print(set_s)
# Out:
# <class 'str'>
# Geeks
# <class 'set'>
# {'k', 'G', 'e', 's'}
